# %% [markdown]
# # Gender Prediction

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix

# %% [markdown]
# ## Load Dataset

# %%
data = pd.read_csv('dataset/gender_classification_v7.csv')

# %%
data.head()
# Out:
#    long_hair  forehead_width_cm  forehead_height_cm  nose_wide  nose_long  \
# 0          1               11.8                 6.1          1          0
# 1          0               14.0                 5.4          0          0
# 2          0               11.8                 6.3          1          1
# 3          0               14.4                 6.1          0          1
# 4          1               13.5                 5.9          0          0
#
#    lips_thin  distance_nose_to_lip_long  gender
# 0          1                          1    Male
# 1          1                          0  Female
# 2          1                          1    Male
# 3          1                          1    Male
# 4          0                          0  Female

# %%
data.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 5001 entries, 0 to 5000
# Data columns (total 8 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   long_hair                  5001 non-null   int64
#  1   forehead_width_cm          5001 non-null   float64
#  2   forehead_height_cm         5001 non-null   float64
#  3   nose_wide                  5001 non-null   int64
#  4   nose_long                  5001 non-null   int64
#  5   lips_thin                  5001 non-null   int64
#  6   distance_nose_to_lip_long  5001 non-null   int64
#  7   gender                     5001 non-null   str
# dtypes: float64(2), int64(5), str(1)
# memory usage: 312.7 KB

# %%
data.isna().sum()
# Out:
# long_hair                    0
# forehead_width_cm            0
# forehead_height_cm           0
# nose_wide                    0
# nose_long                    0
# lips_thin                    0
# distance_nose_to_lip_long    0
# gender                       0
# dtype: int64

# %%
data.describe()
# Out:
#          long_hair  forehead_width_cm  forehead_height_cm    nose_wide  \
# count  5001.000000        5001.000000         5001.000000  5001.000000
# mean      0.869626          13.181484            5.946311     0.493901
# std       0.336748           1.107128            0.541268     0.500013
# min       0.000000          11.400000            5.100000     0.000000
# 25%       1.000000          12.200000            5.500000     0.000000
# 50%       1.000000          13.100000            5.900000     0.000000
# 75%       1.000000          14.000000            6.400000     1.000000
# max       1.000000          15.500000            7.100000     1.000000
#
#          nose_long    lips_thin  distance_nose_to_lip_long
# count  5001.000000  5001.000000                5001.000000
# mean      0.507898     0.493101                   0.498900
# std       0.499988     0.500002                   0.500049
# min       0.000000     0.000000                   0.000000
# ...

# %% [markdown]
# ## Features and Target

# %%
X = data.drop(['gender'], axis=1)
X.head()
# Out:
#    long_hair  forehead_width_cm  forehead_height_cm  nose_wide  nose_long  \
# 0          1               11.8                 6.1          1          0
# 1          0               14.0                 5.4          0          0
# 2          0               11.8                 6.3          1          1
# 3          0               14.4                 6.1          0          1
# 4          1               13.5                 5.9          0          0
#
#    lips_thin  distance_nose_to_lip_long
# 0          1                          1
# 1          1                          0
# 2          1                          1
# 3          1                          1
# 4          0                          0

# %%
y =  data['gender']
y.value_counts()
# Out:
# gender
# Female    2501
# Male      2500
# Name: count, dtype: int64

# %% [markdown]
# ## Train & Test Split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size= 0.15, shuffle= True)

print(f'X_train Shape: {X_train.shape}')
print(f'X_test Shape: {X_test.shape}')
print(f'y_train Shape: {y_train.shape}')
print(f'y_test Shape: {y_test.shape}')
# Out:
# X_train Shape: (4250, 7)
# X_test Shape: (751, 7)
# y_train Shape: (4250,)
# y_test Shape: (751,)

# %% [markdown]
# ## Random Forest Classifier

# %%
random_forest_classifier_model = RandomForestClassifier(criterion = 'gini',n_estimators=100,max_depth=2,random_state=33)

# %% [markdown]
# ## Model Training

# %%
random_forest_classifier_model.fit(X_train, y_train)
# Out:
# RandomForestClassifier(max_depth=2, random_state=33)

# %% [markdown]
# ## Predictions

# %%
y_pred = random_forest_classifier_model.predict(X_test)

# %%
y_pred_prob = random_forest_classifier_model.predict_proba(X_test)

# %% [markdown]
# ## Model Evaluation

# %%
classification_report  = classification_report(y_test, y_pred)
print(classification_report)
# Out:
#               precision    recall  f1-score   support
#
#       Female       0.97      0.98      0.97       371
#         Male       0.98      0.97      0.97       380
#
#     accuracy                           0.97       751
#    macro avg       0.97      0.97      0.97       751
# weighted avg       0.97      0.97      0.97       751

# %%
CM = confusion_matrix(y_test, y_pred)

plt.figure(figsize=(7, 5))

sns.heatmap(
    CM,
    annot=True,
    fmt='d',
    cmap='Blues',
    xticklabels=['Female', 'Male'],
    yticklabels=['Female', 'Male'],
    linewidths=1,
    linecolor='white',
    cbar=False
)

plt.title('Gender Classification', fontsize=15)
plt.xlabel('Predicted Label', fontsize=12)
plt.ylabel('True Label', fontsize=12)

plt.tight_layout()
plt.show()

# %%
result = pd.DataFrame({
    'y_test': y_test,
    'y_pred': y_pred
})

result.sample(10)
# Out:
#       y_test  y_pred
# 4314    Male    Male
# 493     Male    Male
# 2827    Male    Male
# 4264    Male    Male
# 4895  Female    Male
# 1702    Male    Male
# 1949    Male    Male
# 3477    Male    Male
# 3051  Female  Female
# 1438    Male    Male
